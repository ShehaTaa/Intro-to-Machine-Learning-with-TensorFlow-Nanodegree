# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# TODO: Make all necessary imports.
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as display
from PIL import Image
import numpy as np
import pandas as pd
import json
import warnings
warnings.filterwarnings('ignore')
import time
import logging
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !git clone https://github.com/tensorflow/datasets.git
# %cd datasets
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.
# /content/datasets

# %%
# !pip install -e.
# Out:
# Obtaining file:///content/datasets
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (0.9.0)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (19.3.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (0.3.1.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (1.18.4)
# Requirement already satisfied: promise in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (2.3)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (1.12.0)
# Collecting tensorflow-metadata<0.16,>=0.15
#   Downloading https://files.pythonhosted.org/packages/3b/0c/afb81ea6998f6e26521671585d1cd9d3f7945a8b9834764e91757453dc25/tensorflow_metadata-0.15.2-py2.py3-none-any.whl
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (4.41.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets===3.1.0-nightly) (1.12.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-datasets===3.1.0-nightly) (46.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets===3.1.0-nightly) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets===3.1.0-nightly) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets===3.1.0-nightly) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets===3.1.0-nightly) (3.0.4)
# Requirement already satisfied: googleapis-common-protos in /usr/local/lib/python3.6/dist-packages (from tensorflow-metadata<0.16,>=0.15->tensorflow-datasets===3.1.0-nightly) (1.51.0)
# Installing collected packages: tensorflow-metadata, tensorflow-datasets
#   Found existing installation: tensorflow-metadata 0.21.2
#     Uninstalling tensorflow-metadata-0.21.2:
#       Successfully uninstalled tensorflow-metadata-0.21.2
#   Found existing installation: tensorflow-datasets 2.1.0
#     Uninstalling tensorflow-datasets-2.1.0:
#       Successfully uninstalled tensorflow-datasets-2.1.0
#   Running setup.py develop for tensorflow-datasets
# Successfully installed tensorflow-datasets tensorflow-metadata-0.15.2

# %%
# %cd datasets
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums --datasets=oxford_iiit_pet
# Out:
# [Errno 2] No such file or directory: 'datasets'
# /content/datasets
# 2020-05-16 00:22:49.620089: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# I0516 00:22:51.447376 139795137238912 download_and_prepare.py:201] Running download_and_prepare for dataset(s):
# oxford_iiit_pet
# I0516 00:22:51.557530 139795137238912 dataset_info.py:427] Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: oxford_iiit_pet/3.2.0
# I0516 00:22:52.044099 139795137238912 dataset_info.py:358] Load dataset info from /tmp/tmp60zua4tctfds
# I0516 00:22:52.051126 139795137238912 download_and_prepare.py:139] download_and_prepare for dataset oxford_iiit_pet/3.2.0...
# I0516 00:22:52.051572 139795137238912 dataset_builder.py:345] Generating dataset oxford_iiit_pet (/root/tensorflow_datasets/oxford_iiit_pet/3.2.0)
# Downloading and preparing dataset oxford_iiit_pet/3.2.0 (download: 773.52 MiB, generated: 774.69 MiB, total: 1.51 GiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0516 00:22:52.136319 139795137238912 download_manager.py:477] Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz into /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_pets_imageswMR1o1DWRq_DHWToagdXedb7P88RHpceK3WqG77VVwU.tar.gz.tmp.95ae94df1e524245979dad2d4322ff72...
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0516 00:22:52.138736 139795137238912 download_manager.py:477] Downloading http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz into /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_pets_annotationsL8B_bMDM0_iUhyDddl6Yu-1togBm2g5ZH8E6r80wOQo.tar.gz.tmp.d16f97669a224d24ae8258fb5669fb21...
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   0% 0/18 [00:00<?, ? MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   0% 0/773 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   0% 1/773 [00:00<09:39,  1.33 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   0% 2/773 [00:00<09:39,  1.33 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   0% 3/773 [00:00<09:38,  1.33 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 4/773 [00:00<09:37,  1.33 MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 5/773 [00:00<06:49,  1.87 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 6/773 [00:00<06:49,  1.87 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 7/773 [00:00<06:48,  1.87 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 8/773 [00:00<06:48,  1.87 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 9/773 [00:00<06:47,  1.87 MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 10/773 [00:00<04:50,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   1% 11/773 [00:00<04:49,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:00<?, ? url/s]
# Dl Size...:   2% 12/773 [00:00<04:49,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 13/773 [00:01<04:48,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 14/773 [00:01<04:48,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 15/773 [00:01<04:48,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 16/773 [00:01<04:47,  2.63 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 17/773 [00:01<04:47,  2.63 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 18/773 [00:01<03:23,  3.70 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   2% 19/773 [00:01<03:23,  3.70 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 20/773 [00:01<03:23,  3.70 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 21/773 [00:01<03:23,  3.70 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 22/773 [00:01<03:22,  3.70 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 23/773 [00:01<03:22,  3.70 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 24/773 [00:01<03:22,  3.70 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 25/773 [00:01<02:25,  5.13 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 26/773 [00:01<02:25,  5.13 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   3% 27/773 [00:01<02:25,  5.13 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 28/773 [00:01<02:25,  5.13 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 29/773 [00:01<02:24,  5.13 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 30/773 [00:01<02:24,  5.13 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 31/773 [00:01<02:24,  5.13 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 32/773 [00:01<01:44,  7.10 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 33/773 [00:01<01:44,  7.10 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   4% 34/773 [00:01<01:44,  7.10 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   5% 35/773 [00:01<01:44,  7.10 MiB/s]
#
# Dl Completed...:   0% 0/2 [00:01<?, ? url/s]
# Dl Size...:   5% 36/773 [00:01<01:43,  7.10 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:01<00:01,  1.37s/ url]
# Dl Size...:   5% 36/773 [00:01<01:43,  7.10 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:01<00:01,  1.37s/ url]
# Dl Size...:   5% 36/773 [00:01<01:43,  7.10 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:01<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:01<00:01,  1.37s/ url]
# Dl Size...:   5% 37/773 [00:01<01:39,  7.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:01<00:01,  1.37s/ url]
# Dl Size...:   5% 38/773 [00:01<01:39,  7.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   5% 39/773 [00:02<01:39,  7.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   5% 40/773 [00:02<01:38,  7.41 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:02<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   5% 41/773 [00:02<01:30,  8.11 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   5% 42/773 [00:02<01:30,  8.11 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   6% 43/773 [00:02<01:29,  8.11 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:02<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   6% 44/773 [00:02<01:23,  8.74 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   6% 45/773 [00:02<01:23,  8.74 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   6% 46/773 [00:02<01:23,  8.74 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:02<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   6% 47/773 [00:02<01:18,  9.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:02<00:01,  1.37s/ url]
# Dl Size...:   6% 48/773 [00:02<01:18,  9.26 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:02<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   6% 49/773 [00:03<01:13,  9.84 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   6% 50/773 [00:03<01:13,  9.84 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:03<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 51/773 [00:03<01:13,  9.85 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 52/773 [00:03<01:13,  9.85 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:03<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 53/773 [00:03<01:07, 10.66 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 54/773 [00:03<01:07, 10.66 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:03<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 55/773 [00:03<01:06, 10.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 56/773 [00:03<01:06, 10.72 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:03<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   7% 57/773 [00:03<01:06, 10.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   8% 58/773 [00:03<01:06, 10.71 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:03<?, ? file/s]
# Dl Completed...:  50% 1/2 [00:03<00:01,  1.37s/ url]
# Dl Size...:   8% 59/773 [00:03<01:08, 10.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 60/773 [00:04<01:08, 10.39 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:04<?, ? file/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 60/773 [00:04<01:08, 10.39 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 61/773 [00:04<01:03, 11.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 62/773 [00:04<01:02, 11.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 63/773 [00:04<01:02, 11.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 64/773 [00:04<01:02, 11.30 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   8% 65/773 [00:04<00:49, 14.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 66/773 [00:04<00:49, 14.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 67/773 [00:04<00:49, 14.37 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 68/773 [00:04<00:41, 16.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 69/773 [00:04<00:41, 16.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 70/773 [00:04<00:41, 16.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 71/773 [00:04<00:41, 16.86 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 72/773 [00:04<00:34, 20.24 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:   9% 73/773 [00:04<00:34, 20.24 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 74/773 [00:04<00:34, 20.24 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 75/773 [00:04<00:34, 20.24 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 76/773 [00:04<00:31, 22.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 77/773 [00:04<00:31, 22.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 78/773 [00:04<00:31, 22.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 79/773 [00:04<00:31, 22.13 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 80/773 [00:04<00:28, 24.47 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  10% 81/773 [00:04<00:28, 24.47 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 82/773 [00:04<00:28, 24.47 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 83/773 [00:04<00:28, 24.47 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 84/773 [00:04<00:25, 26.80 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 85/773 [00:04<00:25, 26.80 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 86/773 [00:04<00:25, 26.80 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 87/773 [00:04<00:25, 26.80 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:04<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  11% 88/773 [00:04<00:25, 27.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  12% 89/773 [00:04<00:25, 27.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:04<00:01,  1.37s/ url]
# Dl Size...:  12% 90/773 [00:04<00:25, 27.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  12% 91/773 [00:05<00:24, 27.30 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  12% 92/773 [00:05<00:23, 29.50 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  12% 93/773 [00:05<00:23, 29.50 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  12% 94/773 [00:05<00:23, 29.50 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  12% 95/773 [00:05<00:22, 29.50 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  12% 96/773 [00:05<00:22, 30.59 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 97/773 [00:05<00:22, 30.59 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 98/773 [00:05<00:22, 30.59 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 99/773 [00:05<00:22, 30.59 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 100/773 [00:05<00:22, 30.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 101/773 [00:05<00:22, 30.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 102/773 [00:05<00:22, 30.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 103/773 [00:05<00:22, 30.37 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  13% 104/773 [00:05<00:21, 31.47 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 105/773 [00:05<00:21, 31.47 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 106/773 [00:05<00:21, 31.47 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 107/773 [00:05<00:21, 31.47 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 108/773 [00:05<00:21, 31.05 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 109/773 [00:05<00:21, 31.05 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 110/773 [00:05<00:21, 31.05 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 111/773 [00:05<00:21, 31.05 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  14% 112/773 [00:05<00:20, 31.82 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 113/773 [00:05<00:20, 31.82 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 114/773 [00:05<00:20, 31.82 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 115/773 [00:05<00:20, 31.82 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 116/773 [00:05<00:20, 32.22 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 117/773 [00:05<00:20, 32.22 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 118/773 [00:05<00:20, 32.22 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  15% 119/773 [00:05<00:20, 32.22 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:05<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  16% 120/773 [00:05<00:20, 31.64 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  16% 121/773 [00:05<00:20, 31.64 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:05<00:01,  1.37s/ url]
# Dl Size...:  16% 122/773 [00:05<00:20, 31.64 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  16% 123/773 [00:06<00:20, 31.64 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  16% 124/773 [00:06<00:20, 32.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  16% 125/773 [00:06<00:20, 32.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  16% 126/773 [00:06<00:19, 32.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  16% 127/773 [00:06<00:19, 32.39 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 128/773 [00:06<00:19, 32.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 129/773 [00:06<00:19, 32.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 130/773 [00:06<00:19, 32.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 131/773 [00:06<00:19, 32.86 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 132/773 [00:06<00:19, 32.22 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 133/773 [00:06<00:19, 32.22 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 134/773 [00:06<00:19, 32.22 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  17% 135/773 [00:06<00:19, 32.22 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 136/773 [00:06<00:19, 32.18 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 137/773 [00:06<00:19, 32.18 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 138/773 [00:06<00:19, 32.18 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 139/773 [00:06<00:19, 32.18 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 140/773 [00:06<00:19, 32.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 141/773 [00:06<00:19, 32.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 142/773 [00:06<00:19, 32.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  18% 143/773 [00:06<00:19, 32.71 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 144/773 [00:06<00:19, 32.75 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 145/773 [00:06<00:19, 32.75 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 146/773 [00:06<00:19, 32.75 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 147/773 [00:06<00:19, 32.75 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 148/773 [00:06<00:19, 32.38 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 149/773 [00:06<00:19, 32.38 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  19% 150/773 [00:06<00:19, 32.38 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  20% 151/773 [00:06<00:19, 32.38 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:06<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  20% 152/773 [00:06<00:19, 32.04 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  20% 153/773 [00:06<00:19, 32.04 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:06<00:01,  1.37s/ url]
# Dl Size...:  20% 154/773 [00:06<00:19, 32.04 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  20% 155/773 [00:07<00:19, 32.04 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  20% 156/773 [00:07<00:19, 31.46 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  20% 157/773 [00:07<00:19, 31.46 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  20% 158/773 [00:07<00:19, 31.46 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 159/773 [00:07<00:19, 31.46 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 160/773 [00:07<00:18, 32.90 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 161/773 [00:07<00:18, 32.90 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 162/773 [00:07<00:18, 32.90 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 163/773 [00:07<00:18, 32.90 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 164/773 [00:07<00:18, 32.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 165/773 [00:07<00:18, 32.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  21% 166/773 [00:07<00:18, 32.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 167/773 [00:07<00:18, 32.26 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 168/773 [00:07<00:18, 32.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 169/773 [00:07<00:18, 32.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 170/773 [00:07<00:18, 32.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 171/773 [00:07<00:18, 32.26 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 172/773 [00:07<00:18, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  22% 173/773 [00:07<00:18, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 174/773 [00:07<00:18, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 175/773 [00:07<00:18, 32.96 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 176/773 [00:07<00:19, 31.15 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 177/773 [00:07<00:19, 31.15 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 178/773 [00:07<00:19, 31.15 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 179/773 [00:07<00:19, 31.15 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 180/773 [00:07<00:18, 32.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  23% 181/773 [00:07<00:18, 32.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  24% 182/773 [00:07<00:18, 32.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  24% 183/773 [00:07<00:18, 32.41 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  24% 184/773 [00:07<00:18, 32.58 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  24% 185/773 [00:07<00:18, 32.58 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  24% 186/773 [00:07<00:18, 32.58 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:07<00:01,  1.37s/ url]
# Dl Size...:  24% 187/773 [00:07<00:17, 32.58 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:07<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  24% 188/773 [00:08<00:18, 31.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  24% 189/773 [00:08<00:18, 31.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 190/773 [00:08<00:18, 31.71 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 191/773 [00:08<00:18, 31.71 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 192/773 [00:08<00:17, 33.09 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 193/773 [00:08<00:17, 33.09 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 194/773 [00:08<00:17, 33.09 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 195/773 [00:08<00:17, 33.09 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 196/773 [00:08<00:17, 32.64 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  25% 197/773 [00:08<00:17, 32.64 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 198/773 [00:08<00:17, 32.64 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 199/773 [00:08<00:17, 32.64 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 200/773 [00:08<00:17, 32.02 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 201/773 [00:08<00:17, 32.02 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 202/773 [00:08<00:17, 32.02 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 203/773 [00:08<00:17, 32.02 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  26% 204/773 [00:08<00:17, 33.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 205/773 [00:08<00:17, 33.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 206/773 [00:08<00:17, 33.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 207/773 [00:08<00:16, 33.30 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 208/773 [00:08<00:18, 31.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 209/773 [00:08<00:18, 31.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 210/773 [00:08<00:17, 31.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 211/773 [00:08<00:17, 31.30 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  27% 212/773 [00:08<00:17, 32.60 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 213/773 [00:08<00:17, 32.60 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 214/773 [00:08<00:17, 32.60 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 215/773 [00:08<00:17, 32.60 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 216/773 [00:08<00:17, 32.34 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 217/773 [00:08<00:17, 32.34 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 218/773 [00:08<00:17, 32.34 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:08<00:01,  1.37s/ url]
# Dl Size...:  28% 219/773 [00:08<00:17, 32.34 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:08<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  28% 220/773 [00:09<00:17, 31.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 221/773 [00:09<00:17, 31.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 222/773 [00:09<00:17, 31.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 223/773 [00:09<00:17, 31.63 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 224/773 [00:09<00:16, 32.66 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 225/773 [00:09<00:16, 32.66 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 226/773 [00:09<00:16, 32.66 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 227/773 [00:09<00:16, 32.66 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  29% 228/773 [00:09<00:16, 33.20 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 229/773 [00:09<00:16, 33.20 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 230/773 [00:09<00:16, 33.20 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 231/773 [00:09<00:16, 33.20 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 232/773 [00:09<00:17, 31.69 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 233/773 [00:09<00:17, 31.69 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 234/773 [00:09<00:17, 31.69 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  30% 235/773 [00:09<00:16, 31.69 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 236/773 [00:09<00:16, 32.99 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 237/773 [00:09<00:16, 32.99 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 238/773 [00:09<00:16, 32.99 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 239/773 [00:09<00:16, 32.99 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 240/773 [00:09<00:17, 31.29 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 241/773 [00:09<00:17, 31.29 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 242/773 [00:09<00:16, 31.29 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  31% 243/773 [00:09<00:16, 31.29 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 244/773 [00:09<00:16, 32.59 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 245/773 [00:09<00:16, 32.59 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 246/773 [00:09<00:16, 32.59 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 247/773 [00:09<00:16, 32.59 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 248/773 [00:09<00:16, 32.68 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 249/773 [00:09<00:16, 32.68 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 250/773 [00:09<00:16, 32.68 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:09<00:01,  1.37s/ url]
# Dl Size...:  32% 251/773 [00:09<00:15, 32.68 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:09<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 252/773 [00:10<00:16, 31.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 253/773 [00:10<00:16, 31.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 254/773 [00:10<00:16, 31.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 255/773 [00:10<00:16, 31.37 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 256/773 [00:10<00:15, 32.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 257/773 [00:10<00:15, 32.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  33% 258/773 [00:10<00:15, 32.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 259/773 [00:10<00:15, 32.63 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 260/773 [00:10<00:16, 31.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 261/773 [00:10<00:16, 31.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 262/773 [00:10<00:16, 31.37 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 263/773 [00:10<00:16, 31.37 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 264/773 [00:10<00:15, 32.01 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 265/773 [00:10<00:15, 32.01 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  34% 266/773 [00:10<00:15, 32.01 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 267/773 [00:10<00:15, 32.01 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 268/773 [00:10<00:15, 33.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 269/773 [00:10<00:14, 33.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 270/773 [00:10<00:14, 33.63 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 271/773 [00:10<00:14, 33.63 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 272/773 [00:10<00:16, 31.20 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 273/773 [00:10<00:16, 31.20 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  35% 274/773 [00:10<00:15, 31.20 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 275/773 [00:10<00:15, 31.20 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 276/773 [00:10<00:15, 32.49 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 277/773 [00:10<00:15, 32.49 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 278/773 [00:10<00:15, 32.49 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 279/773 [00:10<00:15, 32.49 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 280/773 [00:10<00:14, 33.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 281/773 [00:10<00:14, 33.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  36% 282/773 [00:10<00:14, 33.26 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:10<00:01,  1.37s/ url]
# Dl Size...:  37% 283/773 [00:10<00:14, 33.26 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:10<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  37% 284/773 [00:11<00:15, 31.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  37% 285/773 [00:11<00:15, 31.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  37% 286/773 [00:11<00:15, 31.39 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  37% 287/773 [00:11<00:15, 31.39 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  37% 288/773 [00:11<00:14, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  37% 289/773 [00:11<00:14, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 290/773 [00:11<00:14, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 291/773 [00:11<00:14, 32.96 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 292/773 [00:11<00:15, 31.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 293/773 [00:11<00:15, 31.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 294/773 [00:11<00:15, 31.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 295/773 [00:11<00:15, 31.72 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 296/773 [00:11<00:14, 32.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  38% 297/773 [00:11<00:14, 32.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 298/773 [00:11<00:14, 32.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 299/773 [00:11<00:14, 32.13 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 300/773 [00:11<00:14, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 301/773 [00:11<00:14, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 302/773 [00:11<00:14, 32.96 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 303/773 [00:11<00:14, 32.96 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 304/773 [00:11<00:14, 31.55 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  39% 305/773 [00:11<00:14, 31.55 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 306/773 [00:11<00:14, 31.55 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 307/773 [00:11<00:14, 31.55 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 308/773 [00:11<00:14, 32.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 309/773 [00:11<00:14, 32.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 310/773 [00:11<00:14, 32.41 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 311/773 [00:11<00:14, 32.41 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 312/773 [00:11<00:13, 33.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  40% 313/773 [00:11<00:13, 33.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  41% 314/773 [00:11<00:13, 33.86 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  41% 315/773 [00:11<00:13, 33.86 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:11<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:11<00:01,  1.37s/ url]
# Dl Size...:  41% 316/773 [00:11<00:14, 31.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  41% 317/773 [00:12<00:14, 31.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  41% 318/773 [00:12<00:14, 31.72 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  41% 319/773 [00:12<00:14, 31.72 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  41% 320/773 [00:12<00:14, 32.31 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 321/773 [00:12<00:13, 32.31 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 322/773 [00:12<00:13, 32.31 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 323/773 [00:12<00:13, 32.31 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 324/773 [00:12<00:13, 33.82 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 325/773 [00:12<00:13, 33.82 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 326/773 [00:12<00:13, 33.82 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 327/773 [00:12<00:13, 33.82 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  42% 328/773 [00:12<00:14, 31.17 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 329/773 [00:12<00:14, 31.17 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 330/773 [00:12<00:14, 31.17 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 331/773 [00:12<00:14, 31.17 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 332/773 [00:12<00:13, 33.04 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 333/773 [00:12<00:13, 33.04 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 334/773 [00:12<00:13, 33.04 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 335/773 [00:12<00:13, 33.04 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  43% 336/773 [00:12<00:13, 31.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 337/773 [00:12<00:13, 31.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 338/773 [00:12<00:13, 31.30 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 339/773 [00:12<00:13, 31.30 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 340/773 [00:12<00:13, 32.33 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 341/773 [00:12<00:13, 32.33 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 342/773 [00:12<00:13, 32.33 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  44% 343/773 [00:12<00:13, 32.33 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  45% 344/773 [00:12<00:12, 33.25 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  45% 345/773 [00:12<00:12, 33.25 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  45% 346/773 [00:12<00:12, 33.25 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  45% 347/773 [00:12<00:12, 33.25 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:12<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:12<00:01,  1.37s/ url]
# Dl Size...:  45% 348/773 [00:12<00:13, 32.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  45% 349/773 [00:13<00:13, 32.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  45% 350/773 [00:13<00:13, 32.13 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  45% 351/773 [00:13<00:13, 32.13 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 352/773 [00:13<00:12, 32.42 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 353/773 [00:13<00:12, 32.42 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 354/773 [00:13<00:12, 32.42 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 355/773 [00:13<00:12, 32.42 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 356/773 [00:13<00:13, 32.02 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 357/773 [00:13<00:12, 32.02 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 358/773 [00:13<00:12, 32.02 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  46% 359/773 [00:13<00:12, 32.02 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 360/773 [00:13<00:12, 32.53 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 361/773 [00:13<00:12, 32.53 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 362/773 [00:13<00:12, 32.53 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 363/773 [00:13<00:12, 32.53 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 364/773 [00:13<00:12, 32.60 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 365/773 [00:13<00:12, 32.60 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 366/773 [00:13<00:12, 32.60 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  47% 367/773 [00:13<00:12, 32.60 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 368/773 [00:13<00:12, 31.99 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 369/773 [00:13<00:12, 31.99 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 370/773 [00:13<00:12, 31.99 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 371/773 [00:13<00:12, 31.99 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 372/773 [00:13<00:12, 31.89 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 373/773 [00:13<00:12, 31.89 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  48% 374/773 [00:13<00:12, 31.89 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  49% 375/773 [00:13<00:12, 31.89 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:13<00:00,  4.10s/ file]
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  49% 376/773 [00:13<00:12, 31.73 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  49% 377/773 [00:13<00:12, 31.73 MiB/s]
#
# Dl Completed...:  50% 1/2 [00:13<00:01,  1.37s/ url]
# Dl Size...:  49% 378/773 [00:13<00:12, 31.73 MiB/s]
# ...
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 3680
#         }
#         unique: 3680
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         avg_length: 102707.1015625
#         rank_histogram {
#           buckets {
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 1
#             high_rank: 1
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 2
#             high_rank: 2
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 3
#             high_rank: 3
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 4
#             high_rank: 4
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 5
#             high_rank: 5
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 6
#             high_rank: 6
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 7
#             high_rank: 7
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 8
#             high_rank: 8
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 9
#             high_rank: 9
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#         }
#       }
#       path {
#         step: "image"
#       }
#     }
#     features {
#       type: STRING
#       string_stats {
#         common_stats {
#           num_non_missing: 3680
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 3680
#         }
#         unique: 3680
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         top_values {
#           value: "__BYTES_VALUE__"
#           frequency: 1.0
#         }
#         avg_length: 2746.01708984375
#         rank_histogram {
#           buckets {
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 1
#             high_rank: 1
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 2
#             high_rank: 2
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 3
#             high_rank: 3
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 4
#             high_rank: 4
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 5
#             high_rank: 5
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 6
#             high_rank: 6
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 7
#             high_rank: 7
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 8
#             high_rank: 8
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#           buckets {
#             low_rank: 9
#             high_rank: 9
#             label: "__BYTES_VALUE__"
#             sample_count: 1.0
#           }
#         }
#       }
#       path {
#         step: "segmentation_mask"
#       }
#     }
#     features {
#       num_stats {
#         common_stats {
#           num_non_missing: 3680
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 3680
#         }
#         mean: 18.023641304347827
#         std_dev: 10.69039266989547
#         num_zeros: 100
#         median: 18.0
#         max: 36.0
#         histograms {
#           buckets {
#             high_value: 3.6
#             sample_count: 399.648
#           }
#           buckets {
#             low_value: 3.6
#             high_value: 7.2
#             sample_count: 395.96799999999996
#           }
#           buckets {
#             low_value: 7.2
#             high_value: 10.8
#             sample_count: 300.28800000000007
#           }
#           buckets {
#             low_value: 10.8
#             high_value: 14.4
#             sample_count: 388.608
#           }
#           buckets {
#             low_value: 14.4
#             high_value: 18.0
#             sample_count: 303.968
#           }
#           buckets {
#             low_value: 18.0
#             high_value: 21.6
#             sample_count: 395.968
#           }
#           buckets {
#             low_value: 21.6
#             high_value: 25.2
#             sample_count: 395.96799999999996
#           }
#           buckets {
#             low_value: 25.2
#             high_value: 28.8
#             sample_count: 300.28800000000007
#           }
#           buckets {
#             low_value: 28.8
#             high_value: 32.4
#             sample_count: 399.64799999999997
#           }
#           buckets {
#             low_value: 32.4
#             high_value: 36.0
#             sample_count: 399.648
#           }
#         }
#         histograms {
#           buckets {
#             high_value: 3.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 3.0
#             high_value: 7.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 7.0
#             high_value: 11.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 11.0
#             high_value: 14.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 14.0
#             high_value: 18.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 18.0
#             high_value: 22.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 22.0
#             high_value: 25.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 25.0
#             high_value: 29.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 29.0
#             high_value: 33.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 33.0
#             high_value: 36.0
#             sample_count: 368.0
#           }
#           type: QUANTILES
#         }
#       }
#       path {
#         step: "label"
#       }
#     }
#     features {
#       num_stats {
#         common_stats {
#           num_non_missing: 3680
#           min_num_values: 1
#           max_num_values: 1
#           avg_num_values: 1.0
#           num_values_histogram {
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             buckets {
#               low_value: 1.0
#               high_value: 1.0
#               sample_count: 368.0
#             }
#             type: QUANTILES
#           }
#           tot_num_values: 3680
#         }
#         mean: 0.6771739130434783
#         std_dev: 0.4675568463158913
#         num_zeros: 1188
#         median: 1.0
#         max: 1.0
#         histograms {
#           buckets {
#             high_value: 0.1
#             sample_count: 1185.328
#           }
#           buckets {
#             low_value: 0.1
#             high_value: 0.2
#             sample_count: 0.36800000000000005
#           }
#           buckets {
#             low_value: 0.2
#             high_value: 0.30000000000000004
#             sample_count: 0.36800000000000016
#           }
#           buckets {
#             low_value: 0.30000000000000004
#             high_value: 0.4
#             sample_count: 0.36799999999999994
#           }
#           buckets {
#             low_value: 0.4
#             high_value: 0.5
#             sample_count: 0.36799999999999994
#           }
#           buckets {
#             low_value: 0.5
#             high_value: 0.6000000000000001
#             sample_count: 0.3680000000000003
#           }
#           buckets {
#             low_value: 0.6000000000000001
#             high_value: 0.7000000000000001
#             sample_count: 0.36799999999999994
#           }
#           buckets {
#             low_value: 0.7000000000000001
#             high_value: 0.8
#             sample_count: 0.36799999999999994
#           }
#           buckets {
#             low_value: 0.8
#             high_value: 0.9
#             sample_count: 0.36799999999999994
#           }
#           buckets {
#             low_value: 0.9
#             high_value: 1.0
#             sample_count: 2491.728
#           }
#         }
#         histograms {
#           buckets {
#             sample_count: 368.0
#           }
#           buckets {
#             sample_count: 368.0
#           }
#           buckets {
#             sample_count: 368.0
#           }
#           buckets {
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 368.0
#           }
#           type: QUANTILES
#         }
#       }
#       path {
#         step: "species"
#       }
#     }
#   }
#   shard_lengths: 920
#   shard_lengths: 920
#   shard_lengths: 920
#   shard_lengths: 920
#   num_bytes: 388545440
# }
# supervised_keys {
#   input: "image"
#   output: "label"
# }
# version: "3.2.0"
# download_size: 811092049

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# TODO: Load the dataset with TensorFlow Datasets.
dataset, info = tfds.load("oxford_flowers102",with_info=True,download=True)
# TODO: Create a training set, a validation set and a test set.
train_set = dataset['train']
test_set = dataset['test']
val_set = dataset['validation']

# %%
info.features['label'].num_classes, info.splits['train'].num_examples
# Out:
# (102, 1020)

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.
train_egs = info.splits['train'].num_examples
test_egs = info.splits['test'].num_examples
val_egs = info.splits['validation'].num_examples
print("There are {} images in the training set".format(train_egs))
print("There are {} images in the training set".format(val_egs))
print('There are {} images in the test set'.format(test_egs))
# print(train_egs, test_egs, val_egs)

# TODO: Get the number of classes in the dataset from the dataset info.
num_classes = info.features['label'].num_classes
# print(num_classes)
print('There are {} classes in our dataset'.format(num_classes))
# Out:
# There are 1020 images in the training set
# There are 1020 images in the training set
# There are 6149 images in the test set
# There are 102 classes in our dataset

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
for img in train_set.take(3):
    image,label,shape = img['image'], img['label'], img['image'].shape
    print(('Image3 label is : {0} and shape is : {1}').format(label,shape))
# Out:
# Image3 label is : 72 and shape is : (500, 667, 3)
# Image3 label is : 84 and shape is : (500, 666, 3)
# Image3 label is : 70 and shape is : (670, 500, 3)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
for img in train_set.take(1):
    image,label = img['image'], img['label']
    plt.imshow(image.numpy())
    plt.title(label.numpy())

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
for img in train_set.take(2):
    image,label = img['image'], img['label']
    plt.imshow(image.numpy())
    plt.title(label.numpy())

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
# checking the minimum and maximum label value in the "train_set"
minx = 1000
maxx = -1
for i in training_set.take(1000):
    minx = min(i['label'].numpy(), minx)
    maxx = max(i['label'].numpy(), maxx)
minx, maxx
# Out:
# (0, 101)

# %%
# checking the minimum and maximum label value in the "test_set"
minx = 1000
maxx = -1
for i in test_set.take(1000):
    minx = min(i['label'].numpy(), minx)
    maxx = max(i['label'].numpy(), maxx)
minx, maxx
# Out:
# (0, 101)

# %%
# checking the minimum and maximum label value in the "val_set"
minx = 1000
maxx = -1
for i in val_set.take(1000):
    minx = min(i['label'].numpy(), minx)
    maxx = max(i['label'].numpy(), maxx)
minx, maxx
# Out:
# (0, 101)

# %%
from google.colab import drive
drive.mount('/content/my-drive/', force_remount=True)
# Out:
# Mounted at /content/my-drive/

# %% [markdown]
# ### Reading the class names from the json file

# %%
with open('/content/my-drive/My Drive/label_map.json', 'r') as f:
    class_names = json.load(f)
print(json.dumps(class_names, indent=4))
# Out:
# {
#     "21": "fire lily",
#     "3": "canterbury bells",
#     "45": "bolero deep blue",
#     "1": "pink primrose",
#     "34": "mexican aster",
#     "27": "prince of wales feathers",
#     "7": "moon orchid",
#     "16": "globe-flower",
#     "25": "grape hyacinth",
#     "26": "corn poppy",
#     "79": "toad lily",
#     "39": "siam tulip",
#     "24": "red ginger",
#     "67": "spring crocus",
#     "35": "alpine sea holly",
#     "32": "garden phlox",
#     "10": "globe thistle",
#     "6": "tiger lily",
#     "93": "ball moss",
#     "33": "love in the mist",
#     "9": "monkshood",
#     "102": "blackberry lily",
#     "14": "spear thistle",
#     "19": "balloon flower",
#     "100": "blanket flower",
#     "13": "king protea",
#     "49": "oxeye daisy",
#     "15": "yellow iris",
#     "61": "cautleya spicata",
#     "31": "carnation",
#     "64": "silverbush",
#     "68": "bearded iris",
#     "63": "black-eyed susan",
#     "69": "windflower",
#     "62": "japanese anemone",
#     "20": "giant white arum lily",
#     "38": "great masterwort",
#     "4": "sweet pea",
#     "86": "tree mallow",
#     "101": "trumpet creeper",
#     "42": "daffodil",
#     "22": "pincushion flower",
#     "2": "hard-leaved pocket orchid",
#     "54": "sunflower",
#     "66": "osteospermum",
#     "70": "tree poppy",
#     "85": "desert-rose",
#     "99": "bromelia",
#     "87": "magnolia",
#     "5": "english marigold",
#     "92": "bee balm",
#     "28": "stemless gentian",
#     "97": "mallow",
#     "57": "gaura",
#     "40": "lenten rose",
#     "47": "marigold",
#     "59": "orange dahlia",
#     "48": "buttercup",
#     "55": "pelargonium",
#     "36": "ruby-lipped cattleya",
#     "91": "hippeastrum",
#     "29": "artichoke",
#     "71": "gazania",
#     "90": "canna lily",
#     "18": "peruvian lily",
#     "98": "mexican petunia",
#     "8": "bird of paradise",
#     "30": "sweet william",
#     "17": "purple coneflower",
#     "52": "wild pansy",
#     "84": "columbine",
#     "12": "colt's foot",
#     "11": "snapdragon",
#     "96": "camellia",
#     "23": "fritillary",
#     "50": "common dandelion",
#     "44": "poinsettia",
#     "53": "primula",
#     "72": "azalea",
#     "65": "californian poppy",
#     "80": "anthurium",
#     "76": "morning glory",
#     "37": "cape flower",
#     "56": "bishop of llandaff",
#     "60": "pink-yellow dahlia",
#     "82": "clematis",
#     "58": "geranium",
#     "75": "thorn apple",
#     "41": "barbeton daisy",
#     "95": "bougainvillea",
#     "43": "sword lily",
#     "83": "hibiscus",
#     "78": "lotus lotus",
#     "88": "cyclamen",
#     "94": "foxglove",
#     "81": "frangipani",
#     "74": "rose",
#     "89": "watercress",
#     "73": "water lily",
#     "46": "wallflower",
#     "77": "passion flower",
#     "51": "petunia"
# }

# %% [markdown]
# **Class names contain index from 1 to 102, whereas the datasets have label indices from 0 to 101, hence remapping**

# %%
class_names_new = dict()
for key in class_names:
    class_names_new[str(int(key)-1)] = class_names[key]

# %%
print(class_names_new)
# Out:
# {'20': 'fire lily', '2': 'canterbury bells', '44': 'bolero deep blue', '0': 'pink primrose', '33': 'mexican aster', '26': 'prince of wales feathers', '6': 'moon orchid', '15': 'globe-flower', '24': 'grape hyacinth', '25': 'corn poppy', '78': 'toad lily', '38': 'siam tulip', '23': 'red ginger', '66': 'spring crocus', '34': 'alpine sea holly', '31': 'garden phlox', '9': 'globe thistle', '5': 'tiger lily', '92': 'ball moss', '32': 'love in the mist', '8': 'monkshood', '101': 'blackberry lily', '13': 'spear thistle', '18': 'balloon flower', '99': 'blanket flower', '12': 'king protea', '48': 'oxeye daisy', '14': 'yellow iris', '60': 'cautleya spicata', '30': 'carnation', '63': 'silverbush', '67': 'bearded iris', '62': 'black-eyed susan', '68': 'windflower', '61': 'japanese anemone', '19': 'giant white arum lily', '37': 'great masterwort', '3': 'sweet pea', '85': 'tree mallow', '100': 'trumpet creeper', '41': 'daffodil', '21': 'pincushion flower', '1': 'hard-leaved pocket orchid', '53': 'sunflower', '65': 'osteospermum', '69': 'tree poppy', '84': 'desert-rose', '98': 'bromelia', '86': 'magnolia', '4': 'english marigold', '91': 'bee balm', '27': 'stemless gentian', '96': 'mallow', '56': 'gaura', '39': 'lenten rose', '46': 'marigold', '58': 'orange dahlia', '47': 'buttercup', '54': 'pelargonium', '35': 'ruby-lipped cattleya', '90': 'hippeastrum', '28': 'artichoke', '70': 'gazania', '89': 'canna lily', '17': 'peruvian lily', '97': 'mexican petunia', '7': 'bird of paradise', '29': 'sweet william', '16': 'purple coneflower', '51': 'wild pansy', '83': 'columbine', '11': "colt's foot", '10': 'snapdragon', '95': 'camellia', '22': 'fritillary', '49': 'common dandelion', '43': 'poinsettia', '52': 'primula', '71': 'azalea', '64': 'californian poppy', '79': 'anthurium', '75': 'morning glory', '36': 'cape flower', '55': 'bishop of llandaff', '59': 'pink-yellow dahlia', '81': 'clematis', '57': 'geranium', '74': 'thorn apple', '40': 'barbeton daisy', '94': 'bougainvillea', '42': 'sword lily', '82': 'hibiscus', '77': 'lotus lotus', '87': 'cyclamen', '93': 'foxglove', '80': 'frangipani', '73': 'rose', '88': 'watercress', '72': 'water lily', '45': 'wallflower', '76': 'passion flower', '50': 'petunia'}

# %%
len(class_names_new.keys())
# Out:
# 102

# %%
print(class_names)
# Out:
# {'21': 'fire lily', '3': 'canterbury bells', '45': 'bolero deep blue', '1': 'pink primrose', '34': 'mexican aster', '27': 'prince of wales feathers', '7': 'moon orchid', '16': 'globe-flower', '25': 'grape hyacinth', '26': 'corn poppy', '79': 'toad lily', '39': 'siam tulip', '24': 'red ginger', '67': 'spring crocus', '35': 'alpine sea holly', '32': 'garden phlox', '10': 'globe thistle', '6': 'tiger lily', '93': 'ball moss', '33': 'love in the mist', '9': 'monkshood', '102': 'blackberry lily', '14': 'spear thistle', '19': 'balloon flower', '100': 'blanket flower', '13': 'king protea', '49': 'oxeye daisy', '15': 'yellow iris', '61': 'cautleya spicata', '31': 'carnation', '64': 'silverbush', '68': 'bearded iris', '63': 'black-eyed susan', '69': 'windflower', '62': 'japanese anemone', '20': 'giant white arum lily', '38': 'great masterwort', '4': 'sweet pea', '86': 'tree mallow', '101': 'trumpet creeper', '42': 'daffodil', '22': 'pincushion flower', '2': 'hard-leaved pocket orchid', '54': 'sunflower', '66': 'osteospermum', '70': 'tree poppy', '85': 'desert-rose', '99': 'bromelia', '87': 'magnolia', '5': 'english marigold', '92': 'bee balm', '28': 'stemless gentian', '97': 'mallow', '57': 'gaura', '40': 'lenten rose', '47': 'marigold', '59': 'orange dahlia', '48': 'buttercup', '55': 'pelargonium', '36': 'ruby-lipped cattleya', '91': 'hippeastrum', '29': 'artichoke', '71': 'gazania', '90': 'canna lily', '18': 'peruvian lily', '98': 'mexican petunia', '8': 'bird of paradise', '30': 'sweet william', '17': 'purple coneflower', '52': 'wild pansy', '84': 'columbine', '12': "colt's foot", '11': 'snapdragon', '96': 'camellia', '23': 'fritillary', '50': 'common dandelion', '44': 'poinsettia', '53': 'primula', '72': 'azalea', '65': 'californian poppy', '80': 'anthurium', '76': 'morning glory', '37': 'cape flower', '56': 'bishop of llandaff', '60': 'pink-yellow dahlia', '82': 'clematis', '58': 'geranium', '75': 'thorn apple', '41': 'barbeton daisy', '95': 'bougainvillea', '43': 'sword lily', '83': 'hibiscus', '78': 'lotus lotus', '88': 'cyclamen', '94': 'foxglove', '81': 'frangipani', '74': 'rose', '89': 'watercress', '73': 'water lily', '46': 'wallflower', '77': 'passion flower', '51': 'petunia'}

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 

for img in train_set.take(1):
    image,label = img['image'], img['label']
    plt.imshow(image.numpy())
    plt.title(class_names_new[str(label.numpy())])

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 

for img in train_set.take(2):
    image,label = img['image'], img['label']
    plt.imshow(image.numpy())
    plt.title(class_names_new[str(label.numpy())])

# %% [markdown]
# ## Create Pipeline

# %%
IMG_SIZE = 224
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %% [markdown]
# ### Build Model

# %%
# TODO: Build and train your network.
# build model
def build_model():
    # Load the MobileNet pre-trained network from TensorFlow Hub
    mobilenet_class_map_file = "download.tensorflow.org/data/ImageNetLabels.txt"
    feature_extractor_url = "https://tfhub.dev/google/imagenet/mobilenet_v1_050_160/classification/4"
    feature_extractor_layer = hub.KerasLayer(feature_extractor_url, input_shape=IMG_SHAPE, trainable=False)
    
    model = tf.keras.Sequential([feature_extractor_layer,
                                 tf.keras.layers.Dense(600,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(300,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(num_classes, activation='softmax')
                                ])


    '''  
        model = tf.keras.Sequential()
        model.add(hub.KerasLayer(feature_extractor_url, input_shape=IMG_SHAPE, trainable=False))#It returns a 1001-length vector for each image
        model.add(tf.keras.layers.Dense(500,activation='relu'))
        model.add(tf.keras.layers.Dense(num_classes,activation='softmax'))
    '''      
#     model.build([None, 224, 224, 3])
    print(model.summary())
    
    return model

# %% [markdown]
# ### Train Model

# %%
#train model
def train_model():
    model = build_model()
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['acc'])
    
    #callbacks --------
    callback_path = "Trained Model/Weights"+"/best_weights.hdf5"
    checkpoint = tf.keras.callbacks.ModelCheckpoint(callback_path, save_best_only=True, save_weights_only=False)
    
#     hist_call_back = model.fit(X_train, y_train, epochs=4, callbacks=[checkpoint], validation_data=(X_val,y_val), batch_size=BATCH_SIZE,)
#     hist_call_back = model.fit_generator(train_generator, epochs=1, callbacks=[checkpoint],steps_per_epoch=steps_per_epoch, validation_data=val_generator, validation_steps=31)
#     hist_call_back = model
    hist_call_back = model.fit(training_batches, epochs=30, callbacks=[checkpoint], validation_data=validation_batches)
    return model, hist_call_back

# %%
BATCH_SIZE = 32

# %% [markdown]
# ### Normalization

# %%
# Data Normalisation : The training, validation, and testing data is appropriately resized and normalized.
def format_image(img):
    label = img['label']
    label = tf.one_hot(label,num_classes)
#     print(label,tf.one_hot(label,len(class_names_new)))
    img = img['image']

    processed_image = tf.image.resize(img,(IMG_SIZE,IMG_SIZE))
    processed_image /= 255
    
    return processed_image, label

# %% [markdown]
# **The pipeline for each set that returns batches of images, with all the transformations :**

# %%
training_batches = train_set.shuffle(train_egs//4).map(format_image).batch(BATCH_SIZE).prefetch(1)
validation_batches = val_set.shuffle(train_egs//4).map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batches = test_set.shuffle(train_egs//4).map(format_image).batch(BATCH_SIZE).prefetch(1)

# %%
model, history = train_model()#X_train, y_train, X_val, y_val)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              1343049
# _________________________________________________________________
# dense (Dense)                (None, 600)               601200
# _________________________________________________________________
# dropout (Dropout)            (None, 600)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               180300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 102)               30702
# =================================================================
# Total params: 2,155,251
# Trainable params: 812,202
# Non-trainable params: 1,343,049
# _________________________________________________________________
# None
# Epoch 1/30
# 32/32 [==============================] - 4s 119ms/step - loss: 5.6358 - acc: 0.0098 - val_loss: 4.3883 - val_acc: 0.0520
# Epoch 2/30
# 32/32 [==============================] - 4s 114ms/step - loss: 4.3903 - acc: 0.0480 - val_loss: 4.0386 - val_acc: 0.1373
# Epoch 3/30
# 32/32 [==============================] - 4s 116ms/step - loss: 3.9705 - acc: 0.1059 - val_loss: 3.7034 - val_acc: 0.2324
# Epoch 4/30
# 32/32 [==============================] - 4s 116ms/step - loss: 3.5304 - acc: 0.1902 - val_loss: 3.3486 - val_acc: 0.3196
# Epoch 5/30
# 32/32 [==============================] - 4s 115ms/step - loss: 3.1562 - acc: 0.2549 - val_loss: 3.0132 - val_acc: 0.3804
# Epoch 6/30
# 32/32 [==============================] - 4s 114ms/step - loss: 2.8174 - acc: 0.3490 - val_loss: 2.6933 - val_acc: 0.4471
# Epoch 7/30
# 32/32 [==============================] - 4s 113ms/step - loss: 2.4917 - acc: 0.4108 - val_loss: 2.4201 - val_acc: 0.5020
# Epoch 8/30
# 32/32 [==============================] - 4s 115ms/step - loss: 2.1357 - acc: 0.5108 - val_loss: 2.1950 - val_acc: 0.5245
# Epoch 9/30
# 32/32 [==============================] - 4s 114ms/step - loss: 1.8407 - acc: 0.5578 - val_loss: 1.9800 - val_acc: 0.5676
# Epoch 10/30
# 32/32 [==============================] - 4s 114ms/step - loss: 1.6388 - acc: 0.5922 - val_loss: 1.7987 - val_acc: 0.6039
# Epoch 11/30
# 32/32 [==============================] - 4s 114ms/step - loss: 1.4275 - acc: 0.6451 - val_loss: 1.6626 - val_acc: 0.6206
# Epoch 12/30
# 32/32 [==============================] - 4s 115ms/step - loss: 1.2591 - acc: 0.6912 - val_loss: 1.5403 - val_acc: 0.6490
# Epoch 13/30
# 32/32 [==============================] - 4s 114ms/step - loss: 1.0999 - acc: 0.7294 - val_loss: 1.4674 - val_acc: 0.6569
# Epoch 14/30
# 32/32 [==============================] - 4s 116ms/step - loss: 0.9914 - acc: 0.7578 - val_loss: 1.3824 - val_acc: 0.6578
# Epoch 15/30
# 32/32 [==============================] - 4s 114ms/step - loss: 0.8665 - acc: 0.7941 - val_loss: 1.3356 - val_acc: 0.6794
# Epoch 16/30
# 32/32 [==============================] - 4s 114ms/step - loss: 0.7698 - acc: 0.8235 - val_loss: 1.2742 - val_acc: 0.6775
# Epoch 17/30
# 32/32 [==============================] - 4s 114ms/step - loss: 0.7275 - acc: 0.8216 - val_loss: 1.2190 - val_acc: 0.6951
# Epoch 18/30
# 32/32 [==============================] - 4s 113ms/step - loss: 0.6356 - acc: 0.8529 - val_loss: 1.1658 - val_acc: 0.7147
# Epoch 19/30
# 32/32 [==============================] - 4s 114ms/step - loss: 0.5728 - acc: 0.8627 - val_loss: 1.1354 - val_acc: 0.7059
# Epoch 20/30
# 32/32 [==============================] - 4s 115ms/step - loss: 0.5062 - acc: 0.8961 - val_loss: 1.1009 - val_acc: 0.7304
# Epoch 21/30
# 32/32 [==============================] - 4s 115ms/step - loss: 0.4847 - acc: 0.8892 - val_loss: 1.0806 - val_acc: 0.7186
# Epoch 22/30
# 32/32 [==============================] - 4s 115ms/step - loss: 0.4363 - acc: 0.9078 - val_loss: 1.0601 - val_acc: 0.7265
# Epoch 23/30
# 32/32 [==============================] - 4s 116ms/step - loss: 0.3730 - acc: 0.9196 - val_loss: 1.0333 - val_acc: 0.7265
# Epoch 24/30
# 32/32 [==============================] - 4s 116ms/step - loss: 0.3604 - acc: 0.9186 - val_loss: 1.0256 - val_acc: 0.7333
# Epoch 25/30
# 32/32 [==============================] - 4s 114ms/step - loss: 0.3370 - acc: 0.9294 - val_loss: 1.0141 - val_acc: 0.7324
# Epoch 26/30
# 32/32 [==============================] - 4s 113ms/step - loss: 0.3162 - acc: 0.9324 - val_loss: 1.0120 - val_acc: 0.7412
# Epoch 27/30
# 32/32 [==============================] - 4s 114ms/step - loss: 0.2738 - acc: 0.9451 - val_loss: 0.9811 - val_acc: 0.7422
# Epoch 28/30
# 32/32 [==============================] - 4s 115ms/step - loss: 0.2648 - acc: 0.9461 - val_loss: 0.9693 - val_acc: 0.7510
# Epoch 29/30
# 32/32 [==============================] - 4s 117ms/step - loss: 0.2373 - acc: 0.9510 - val_loss: 0.9830 - val_acc: 0.7363
# Epoch 30/30
# 32/32 [==============================] - 4s 113ms/step - loss: 0.2112 - acc: 0.9686 - val_loss: 0.9541 - val_acc: 0.7422

# %% [markdown]
# ### loss and accuracy values achieved during training for the training and validation set

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
# Accuracy Plots
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %%
# Loss Plots
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO : Print the loss and accuracy values achieved on the entire test set
loss,acc = model.evaluate(test_batches)#x=X_test,y=y_test)
# Out:
# 193/193 [==============================] - 12s 62ms/step - loss: 1.0818 - acc: 0.7198

# %%
print("Loss :",loss,"\nAccuracy :",acc)
# Out:
# Loss : 1.0817897319793701
# Accuracy : 0.719791829586029

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
pip install -q pyyaml h5py

# %%
# TODO: Save your trained model as a Keras model. 
# model_path = 'Trained Model/TrainedModel.h5'
# model.save(model_path)

# !mkdir -p saved_model
model_path = 'saved_model//my_model.h5'
model.save(model_path)

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
loaded_model = tf.keras.models.load_model(model_path,custom_objects={'KerasLayer':hub.KerasLayer})
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              1343049
# _________________________________________________________________
# dense (Dense)                (None, 600)               601200
# _________________________________________________________________
# dropout (Dropout)            (None, 600)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               180300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 102)               30702
# =================================================================
# Total params: 2,155,251
# Trainable params: 812,202
# Non-trainable params: 1,343,049
# _________________________________________________________________

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function

def process_image(numpy_image):
    print(numpy_image.shape)
    tensor_img = tf.image.convert_image_dtype(numpy_image, dtype=tf.int16, saturate=False)
    resized_img = tf.image.resize(numpy_image,(IMG_SIZE,IMG_SIZE)).numpy()
    norm_img = resized_img/255

    return norm_img

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = '/content/my-drive/My Drive//test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()
# Out:
# (591, 500, 3)

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

def predict(image_path, model, top_k):
    
    img = Image.open(image_path)
    test_image = np.asarray(img)

    processed_test_image = process_image(test_image)

    print(processed_test_image.shape, np.expand_dims(processed_test_image,axis=0).shape)
    prob_preds = model.predict(np.expand_dims(processed_test_image,axis=0))
    prob_preds = prob_preds[0].tolist()

#     classes = np.array(sorted(range(len(prob_preds)), key=lambda i: prob_preds[i])[-top_k:])+1
#     classes = sorted(range(len(prob_preds)), key=lambda i: prob_preds[i])[-top_k:]

#     probs = [prob_preds[i] for i in np.argsort(prob_preds)[-top_k:]]
# -------------
#TODO: make these changes in the command line code as well
    values, indices= tf.math.top_k(prob_preds, k=top_k)
#     return values, indices
#     print("jhfdjhdjfh============",values,indices)
#     indices=indices+1
    probs=values.numpy().tolist()#[0]
    classes=indices.numpy().tolist()#[0]

    return probs, classes

# %%
probs, classes = predict('/content/my-drive/My Drive/test_images/orange_dahlia.jpg',loaded_model, 5)
# Out:
# (752, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)

# %%
pred_label_names = [class_names_new[str(idx)] for idx in classes]
print("prediction probabilities :\n",probs)
print('prediction classes:\n',classes)
print('prediction labels:\n',pred_label_names)
# Out:
# prediction probabilities :
#  [0.503149151802063, 0.1823899745941162, 0.12526288628578186, 0.07677871733903885, 0.06214451789855957]
# prediction classes:
#  [58, 70, 40, 4, 59]
# prediction labels:
#  ['orange dahlia', 'gazania', 'barbeton daisy', 'english marigold', 'pink-yellow dahlia']

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
img_path_1 = '/content/my-drive/My Drive/test_images/cautleya_spicata.jpg'
img_path_2 = '/content/my-drive/My Drive/test_images/hard-leaved_pocket_orchid.jpg'
img_path_3 = '/content/my-drive/My Drive/test_images/wild_pansy.jpg'
img_path_4 = '/content/my-drive/My Drive/test_images/orange_dahlia.jpg'

# %%
def plot_image(path, index):
#     print('==',path)
    # Plot
    ax = plt.subplot(2, 2, index*2 + 1)
    
    img = Image.open(path)
    test_image = np.asarray(img)
    img = process_image(test_image)
    
    title = path.rsplit("/",1)[-1]
    plt.title(title)
    plt.imshow(img)
    
    # Make prediction
    probs, labels = predict(path, model, 5)
    print(probs)
    print(labels)
    
    # Get label names
    label_names = [class_names_new[str(idd)] for idd in labels]
    print(label_names)
    
    # Plot bar chart
    ax = plt.subplot(2, 2, index*2 + 2)
    ax.yaxis.tick_right()
    sns.barplot(x=probs, y=label_names, color=sns.color_palette()[0]);

# %%
plt.figure(figsize = (6,10))
plot_image(img_path_1, 0)
plot_image(img_path_2, 1)
plt.show()
# Out:
# (750, 500, 3)
# (750, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.9910658001899719, 0.002850365824997425, 0.0019384712213650346, 0.0009531236137263477, 0.000464662880403921]
# [60, 20, 100, 38, 58]
# ['cautleya spicata', 'fire lily', 'trumpet creeper', 'siam tulip', 'orange dahlia']
# (591, 500, 3)
# (591, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.9917412996292114, 0.007762945257127285, 0.0001976572093553841, 6.58925564493984e-05, 6.020413638907485e-05]
# [1, 6, 79, 72, 30]
# ['hard-leaved pocket orchid', 'moon orchid', 'anthurium', 'water lily', 'carnation']

# %%
plt.figure(figsize = (6,10))
plot_image(img_path_3, 0)
plot_image(img_path_4, 1)
plt.show()
# Out:
# (558, 500, 3)
# (558, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.9286754131317139, 0.015217549167573452, 0.00861753523349762, 0.0067462255246937275, 0.006265134084969759]
# [51, 47, 33, 48, 17]
# ['wild pansy', 'buttercup', 'mexican aster', 'oxeye daisy', 'peruvian lily']
# (752, 500, 3)
# (752, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.503149151802063, 0.1823899745941162, 0.12526288628578186, 0.07677871733903885, 0.06214451789855957]
# [58, 70, 40, 4, 59]
# ['orange dahlia', 'gazania', 'barbeton daisy', 'english marigold', 'pink-yellow dahlia']

# %%
# Printing the outputs from the predict function for input image of orange_dahlia
print(probs)
print(classes)
print(pred_label_names)
# Out:
# [0.503149151802063, 0.1823899745941162, 0.12526288628578186, 0.07677871733903885, 0.06214451789855957]
# [58, 70, 40, 4, 59]
# ['orange dahlia', 'gazania', 'barbeton daisy', 'english marigold', 'pink-yellow dahlia']
